# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Data.csv', encoding ="ISO-8859-1")

# %%
df
# Out:
#             Date  Label                                               Top1  \
# 0     2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1     2000-01-04      0                                          Scorecard
# 2     2000-01-05      0                  Coventry caught on counter by Flo
# 3     2000-01-06      1                      Pilgrim knows how to progress
# 4     2000-01-07      1                               Hitches and Horlocks
# ...          ...    ...                                                ...
# 4096  2016-06-27      0  Barclays and RBS shares suspended from trading...
# 4097  2016-06-28      1  2,500 Scientists To Australia: If You Want To ...
# 4098  2016-06-29      1                   Explosion At Airport In Istanbul
# 4099  2016-06-30      1  Jamaica proposes marijuana dispensers for tour...
# 4100  2016-07-01      1  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import string
import re
from nltk.corpus import stopwords

# Assuming 'df' is the DataFrame containing the data

# Step 1: Data Cleaning and Preprocessing
def clean_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

# Combine all headline columns into a single text representation for each row
headline_columns = [col for col in df.columns if col.startswith('Top')]
df['combined_headlines'] = df[headline_columns].astype(str).agg(' '.join, axis=1)

# Clean the combined text
df['cleaned_text'] = df['combined_headlines'].apply(clean_text)

# %%
df
# Out:
#             Date  Label                                               Top1  \
# 0     2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1     2000-01-04      0                                          Scorecard
# 2     2000-01-05      0                  Coventry caught on counter by Flo
# 3     2000-01-06      1                      Pilgrim knows how to progress
# 4     2000-01-07      1                               Hitches and Horlocks
# ...          ...    ...                                                ...
# 4096  2016-06-27      0  Barclays and RBS shares suspended from trading...
# 4097  2016-06-28      1  2,500 Scientists To Australia: If You Want To ...
# 4098  2016-06-29      1                   Explosion At Airport In Istanbul
# 4099  2016-06-30      1  Jamaica proposes marijuana dispensers for tour...
# 4100  2016-07-01      1  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# ...

# %%
train = df[df['Date']< '20150101']
test = df[df['Date'] > '20141231']

# %% [markdown]
# # Random Forest

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from gensim.models import Word2Vec

def train_and_evaluate_vectorizer(vectorizer, X_train, X_test, y_train, y_test):
    # Transform text data
    X_train_transformed = vectorizer.fit_transform(X_train)
    X_test_transformed = vectorizer.transform(X_test)

    # Initialize and train the Random Forest Classifier
    clf = RandomForestClassifier(n_estimators=100, criterion = 'entropy')
    clf.fit(X_train_transformed, y_train)

    # Predict on the test set
    y_pred = clf.predict(X_test_transformed)

    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    return accuracy, precision, recall, f1

# %%
# Splitting data into X and y
X_train_count = train['cleaned_text']
X_test_count = test['cleaned_text']
y_train = train['Label']
y_test = test['Label']

X_train_tfidf = train['cleaned_text']
X_test_tfidf = test['cleaned_text']

# Count Vectorizer + Random Forest
vectorizer_count = CountVectorizer(ngram_range=(2,2))
accuracy_count, precision_count, recall_count, f1_count = train_and_evaluate_vectorizer(vectorizer_count, X_train_count, X_test_count, y_train, y_test)

# TF-IDF Vectorizer + Random Forest
vectorizer_tfidf = TfidfVectorizer()
accuracy_tfidf, precision_tfidf, recall_tfidf, f1_tfidf = train_and_evaluate_vectorizer(vectorizer_tfidf, X_train_tfidf, X_test_tfidf, y_train, y_test)

# Display results
print("Results for Count Vectorizer + Random Forest:")
print(f"Accuracy: {accuracy_count:.4f}, Precision: {precision_count:.4f}, Recall: {recall_count:.4f}, F1-score: {f1_count:.4f}\n")

print("Results for TF-IDF Vectorizer + Random Forest:")
print(f"Accuracy: {accuracy_tfidf:.4f}, Precision: {precision_tfidf:.4f}, Recall: {recall_tfidf:.4f}, F1-score: {f1_tfidf:.4f}\n")
# Out:
# Results for Count Vectorizer + Random Forest:
# Accuracy: 0.8571, Precision: 0.7828, Recall: 0.9948, F1-score: 0.8761
#
# Results for TF-IDF Vectorizer + Random Forest:
# Accuracy: 0.8545, Precision: 0.8278, Recall: 0.9010, F1-score: 0.8628

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

def train_and_evaluate_vectorizer(vectorizer, X_train, X_test, y_train, y_test):
    # Transform text data
    X_train_transformed = vectorizer.fit_transform(X_train)
    X_test_transformed = vectorizer.transform(X_test)

    # Initialize and train the Naive Bayes Classifier
    clf = MultinomialNB()
    clf.fit(X_train_transformed, y_train)

    # Predict on the test set
    y_pred = clf.predict(X_test_transformed)

    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    return accuracy, precision, recall, f1

# %%
# Splitting data into X and y
X_train_count = train['cleaned_text']
X_test_count = test['cleaned_text']
y_train = train['Label']
y_test = test['Label']

X_train_tfidf = train['cleaned_text']
X_test_tfidf = test['cleaned_text']

# Count Vectorizer + Naive Bayes
vectorizer_count = CountVectorizer(ngram_range=(2,2))
accuracy_count, precision_count, recall_count, f1_count = train_and_evaluate_vectorizer(vectorizer_count, X_train_count, X_test_count, y_train, y_test)

# TF-IDF Vectorizer + Naive Bayes
vectorizer_tfidf = TfidfVectorizer()
accuracy_tfidf, precision_tfidf, recall_tfidf, f1_tfidf = train_and_evaluate_vectorizer(vectorizer_tfidf, X_train_tfidf, X_test_tfidf, y_train, y_test)

# Display results
print("Results for Count Vectorizer + Naive Bayes:")
print(f"Accuracy: {accuracy_count:.4f}, Precision: {precision_count:.4f}, Recall: {recall_count:.4f}, F1-score: {f1_count:.4f}\n")

print("Results for TF-IDF Vectorizer + Naive Bayes:")
print(f"Accuracy: {accuracy_tfidf:.4f}, Precision: {precision_tfidf:.4f}, Recall: {recall_tfidf:.4f}, F1-score: {f1_tfidf:.4f}\n")
# Out:
# Results for Count Vectorizer + Naive Bayes:
# Accuracy: 0.8360, Precision: 0.8186, Recall: 0.8698, F1-score: 0.8434
#
# Results for TF-IDF Vectorizer + Naive Bayes:
# Accuracy: 0.5212, Precision: 0.5147, Recall: 1.0000, F1-score: 0.6796
